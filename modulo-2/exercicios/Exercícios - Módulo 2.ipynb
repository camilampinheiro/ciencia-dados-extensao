# %% [markdown]
# # Lista de Exercícios — Módulo 2: Manipulação de Dados com Pandas
#
# Esta lista de exercícios tem como objetivo reforçar os conceitos estudados no **Módulo 2**, envolvendo leitura, exploração, limpeza e manipulação de dados com a biblioteca **Pandas**.
#
# Utilize o dataset `brazilian_cities.csv`, presente na pasta `datasets`.
#
# ## Instruções
#
# - Resolva os exercícios utilizando Python e Pandas;
# - Procure manter o código organizado;
# - Antes de responder, observe bem os dados;
# - Em caso de dúvida, revise o notebook do módulo.
#
# > **Importante:** este arquivo contém apenas os enunciados. As respostas devem ser consultadas no arquivo de gabarito.

# %% [markdown]
# ## Exercício 1 — Carregando a base
#
# Carregue o arquivo `brazilian_cities.csv` com o Pandas e responda:
#
# a) Mostre as 5 primeiras linhas da base
# b) Mostre quantas linhas e colunas existem
# c) Mostre os nomes das colunas

# %% [markdown]
# ## Exercício 2 — Explorando os dados
#
# Utilizando o DataFrame carregado:
#
# a) Mostre um resumo da base com `info()`
# b) Gere estatísticas descritivas com `describe()`
# c) Verifique quantos valores nulos existem em cada coluna

# %% [markdown]
# ## Exercício 3 — Selecionando colunas
#
# Crie um novo DataFrame contendo apenas as colunas abaixo:
#
# - `CITY`
# - `STATE`
# - `CAPITAL`
# - `ESTIMATED_POP`
# - `AREA`
# - `GDP`
# - `GDP_CAPITA`
# - `IDHM`
# - `HOTELS`
#
# Depois, exiba as 5 primeiras linhas desse novo DataFrame.

# %% [markdown]
# ## Exercício 4 — Tratando valores nulos
#
# No novo DataFrame criado:
#
# a) Verifique novamente os valores nulos
# b) Preencha a coluna `HOTELS` com 0
# c) Preencha a coluna `IDHM` com a mediana
# d) Verifique novamente se os valores nulos diminuíram

# %% [markdown]
# ## Exercício 5 — Removendo duplicatas
#
# a) Verifique se existem linhas duplicadas
# b) Remova as duplicatas
# c) Mostre a quantidade de duplicatas antes e depois

# %% [markdown]
# ## Exercício 6 — Filtros simples
#
# Utilizando o DataFrame:
#
# a) Mostre apenas os municípios com população estimada maior que 100.000
# b) Mostre apenas os municípios que são capitais
# c) Mostre apenas as capitais com IDHM maior que 0,75

# %% [markdown]
# ## Exercício 7 — Ordenação
#
# a) Ordene os municípios pelo `GDP` do maior para o menor
# b) Ordene os municípios pelo `IDHM` do maior para o menor
# c) Mostre os 5 primeiros resultados em cada caso

# %% [markdown]
# ## Exercício 8 — Criando novas colunas
#
# Crie as seguintes colunas:
#
# a) `DENSIDADE_DEMOGRAFICA`, dividindo a população estimada pela área
# b) `CARROS_POR_HABITANTE`, dividindo a quantidade de carros pela população estimada
#
# Depois, mostre as 5 primeiras linhas com essas novas colunas.

# %% [markdown]
# ## Exercício 9 — Agrupamento
#
# a) Calcule o PIB médio (`GDP`) por estado
# b) Calcule o IDHM médio por estado
# c) Conte quantos municípios existem por estado

# %% [markdown]
# ## Exercício 10 — Estatística descritiva
#
# Utilizando a coluna `IDHM`, calcule:
#
# a) média
# b) mediana
# c) moda
# d) desvio padrão

# %% [markdown]
# ## Exercício 11 — Interpretação dos dados
#
# Com base nos resultados encontrados ao longo da lista, responda com suas palavras:
#
# a) O que você percebeu sobre os municípios com maior PIB?
# b) As capitais parecem ter IDHM mais alto?
# c) O agrupamento por estado ajuda a entender melhor os dados? Por quê?
