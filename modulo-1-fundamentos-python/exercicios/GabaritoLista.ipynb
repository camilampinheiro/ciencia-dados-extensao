# %% [markdown]
# # Gabarito — Lista de Exercícios
# ## Módulo 1: Fundamentos de Python

# %%
# Exercício 1
print("Olá, seja bem-vindo ao curso de Python para Ciência de Dados!")

# %%
# Exercício 2
nome = "Maria"
idade = 25
nota_final = 8.0
aprovado = True

print("Nome:", nome)
print("Idade:", idade)
print("Nota final:", nota_final)
print("Aprovado:", aprovado)

# %%
# Exercício 3
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

print("Soma:", num1 + num2)
print("Subtração:", num1 - num2)
print("Multiplicação:", num1 * num2)
print("Divisão:", num1 / num2)

# %%
# Exercício 4
idade = int(input("Digite a idade: "))

if idade < 18:
    print("Menor de idade")
else:
    print("Maior de idade")

# %%
# Exercício 5
nota = float(input("Digite a nota do aluno: "))

if nota >= 7:
    print("Aprovado")
elif nota >= 5:
    print("Recuperação")
else:
    print("Reprovado")

# %%
# Exercício 6
for numero in range(1, 11):
    print(numero)

# %%
# Exercício 7
contador = 0

while contador <= 4:
    print(contador)
    contador += 1

# %%
# Exercício 8
frutas = ["maçã", "banana", "uva", "laranja", "abacaxi"]

print("Lista completa:", frutas)
print("Primeiro elemento:", frutas[0])

frutas.append("manga")
print("Lista atualizada:", frutas)

# %%
# Exercício 9
cores = ("azul", "verde", "vermelho")

print(cores[1])

# %%
# Exercício 10
aluno = {
    "nome": "Bruno",
    "idade": 22,
    "curso": "Administração"
}

print(aluno["nome"])

# %%
# Exercício 11
alunos = ["Ana", "Bruno", "Elisa"]

for aluno in alunos:
    print(aluno)

# %%
# Exercício 12
nome_aluna = "Maria"
idade_aluna = 20
curso_aluna = "Ciência de Dados"

print(nome_aluna, idade_aluna, curso_aluna)

# %% [markdown]
# ## Observação
#
# Este gabarito apresenta uma possível solução para cada exercício. Outras respostas também podem ser consideradas corretas, desde que utilizem adequadamente os conceitos introdutórios da linguagem Python trabalhados no Módulo 1.
