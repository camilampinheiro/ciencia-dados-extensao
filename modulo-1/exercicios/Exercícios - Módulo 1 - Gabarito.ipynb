# %% [markdown]
# # Módulo 1 — Gabarito — Lista de Exercícios
#
# Notebook com soluções para exercícios introdutórios de Python.

# %% [markdown]
# ## 1. Imprimir nome, idade e cidade em três linhas

# %%
nome = 'João'
idade = 20
cidade = 'Fortaleza'

print(nome)
print(idade)
print(cidade)

# %% [markdown]
# ## 2. Pedir três números ao usuário e calcular a média

# %%
n1 = float(input('Digite o primeiro número: '))
n2 = float(input('Digite o segundo número: '))
n3 = float(input('Digite o terceiro número: '))

media = (n1 + n2 + n3) / 3
print('Média:', media)

# %% [markdown]
# ## 3. Sistema simples de notas

# %%
nota1 = float(input('Digite a primeira nota: '))
nota2 = float(input('Digite a segunda nota: '))
nota3 = float(input('Digite a terceira nota: '))

media = (nota1 + nota2 + nota3) / 3

print('Média:', media)

if media >= 6:
    print('Aprovado')
else:
    print('Reprovado')

# %% [markdown]
# ## 4. Verificar maioridade

# %%
idade = int(input('Digite sua idade: '))

if idade >= 18:
    print('Maior de idade')
else:
    print('Menor de idade')

# %% [markdown]
# ## 5. Usar for para imprimir números de 0 até 20

# %%
for i in range(21):
    print(i)

# %% [markdown]
# ## 6. Usar while para imprimir números pares entre 0 e 20

# %%
numero = 0

while numero <= 20:
    if numero % 2 == 0:
        print(numero)
    numero += 1

# %% [markdown]
# ## 7. Lista com 5 números e cálculo da média

# %%
numeros = [10, 20, 30, 40, 50]

media = sum(numeros) / len(numeros)
print('Média:', media)

# %% [markdown]
# ## 8. Lista com 5 nomes e impressão com for

# %%
nomes = ['Ana', 'Carlos', 'Maria', 'Pedro', 'Julia']

for nome in nomes:
    print(nome)

# %% [markdown]
# ## 9. Imprimir números de 1 até um número informado pelo usuário

# %%
numero = int(input('Digite um número inteiro: '))

for i in range(1, numero + 1):
    print(i)

# %% [markdown]
# ## 10. Dicionário representando um produto

# %%
produto = {
    'nome': 'Notebook',
    'preco': 3500.00,
    'quantidade': 10
}

print('Produto:', produto['nome'])
print('Preço:', produto['preco'])
